# %% [markdown]
# #FacialKeypointsDetection

# %%
import pandas as pd
import pickle

# %% [markdown]
# ##数据预处理和探索阶段

# %%
Xtrain = pd.read_csv('data/imagesTrain.csv')
train_df = pd.read_csv('data/training.csv')

# %%
Xtrain.head()
# Out:
#    pixel0  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0     238     236     237     238     240     240     239     241     241
# 1     219     215     204     196     204     211     212     200     180
# 2     144     142     159     180     188     188     184     180     167
# 3     193     192     193     194     194     194     193     192     168
# 4     147     148     160     196     215     214     216     217     219
#
#    pixel9    ...      pixel9206  pixel9207  pixel9208  pixel9209  pixel9210  \
# 0     243    ...             33         29         30         34         39
# 1     168    ...              1          1          1          1          1
# 2     132    ...             64         60         56         61         70
# 3     111    ...              1          1          1          1          1
# 4     220    ...             33         34         37         37         43
#
#    pixel9211  pixel9212  pixel9213  pixel9214  pixel9215
# ...

# %%
train_df.head()
# Out:
#    left_eye_center_x  left_eye_center_y  right_eye_center_x  \
# 0          66.033564          39.002274           30.227008
# 1          64.332936          34.970077           29.949277
# 2          65.057053          34.909642           30.903789
# 3          65.225739          37.261774           32.023096
# 4          66.725301          39.621261           32.244810
#
#    right_eye_center_y  left_eye_inner_corner_x  left_eye_inner_corner_y  \
# 0           36.421678                59.582075                39.647423
# 1           33.448715                58.856170                35.274349
# 2           34.909642                59.412000                36.320968
# 3           37.261774                60.003339                39.127179
# 4           38.042032                58.565890                39.621261
#
#    left_eye_outer_corner_x  left_eye_outer_corner_y  right_eye_inner_corner_x  \
# 0                73.130346                39.969997                 36.356571
# ...

# %%
train_df.describe()
# Out:
#        left_eye_center_x  left_eye_center_y  right_eye_center_x  \
# count        7039.000000        7039.000000         7036.000000
# mean           66.359021          37.651234           30.306102
# std             3.448233           3.152926            3.083230
# min            22.763345           1.616512            0.686592
# 25%            65.082895          35.900451           28.783339
# 50%            66.497566          37.528055           30.251378
# 75%            68.024752          39.258449           31.768334
# max            94.689280          80.502649           85.039381
#
#        right_eye_center_y  left_eye_inner_corner_x  left_eye_inner_corner_y  \
# count         7036.000000              2271.000000              2271.000000
# mean            37.976943                59.159339                37.944752
# std              3.033621                 2.690354                 2.307332
# min              4.091264                19.064954                27.190098
# ...

# %% [markdown]
# ##数据中含有空值，只有不部分数据预测了某些特征，例如left_eye_inner_corner,只有2271个数据预测了该值，因此需要划分数据集

# %%
X=pd.concat([Xtrain,train_df],axis=1)

# %%
##保存数据
X.to_pickle('data/Xtrain.pk')

# %% [markdown]
# ###提取数据，将数据划分为两个部分,同时处理空值，采用fill的方式处理

# %%
X= pd.read_pickle('data/Xtrain.pk')

# %%
X1 = X[pd.notnull(X['right_eye_inner_corner_x'])]

# %%
X1.fillna(X1.mean())
X1.head()
# Out:
#    pixel0  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0     238     236     237     238     240     240     239     241     241
# 1     219     215     204     196     204     211     212     200     180
# 2     144     142     159     180     188     188     184     180     167
# 3     193     192     193     194     194     194     193     192     168
# 4     147     148     160     196     215     214     216     217     219
#
#    pixel9            ...              nose_tip_x  nose_tip_y  \
# 0     243            ...               44.420571   57.066803
# 1     168            ...               48.206298   55.660936
# 2     132            ...               47.557263   53.538947
# 3     111            ...               51.885078   54.166539
# 4     220            ...               43.299534   64.889521
#
#    mouth_left_corner_x  mouth_left_corner_y  mouth_right_corner_x  \
# 0            61.195308            79.970165             28.614496
# ...

# %%
temp = train_df.describe()

# %%
#数据对应的列名
cols1 = [i for i in temp.ix['count'].index if temp.ix['count'][i] < 3000]
cols2 = [i for i in temp.ix['count'].index if temp.ix['count'][i] > 3000]

# %%
X1.to_pickle('data\X1.pk')

# %%
X2 = X[pd.notnull(X[cols2[0]])]

# %%
X2.fillna(X2.mean())
X2.to_pickle('data\X2.pk')
